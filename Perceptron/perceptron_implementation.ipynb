# %% [markdown]
# # Basic Perceptron Demo

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("student_exam_data_new.csv")
df
# Out:
#      Study Hours  Previous Exam Score  Pass/Fail
# 0       4.370861            81.889703          0
# 1       9.556429            72.165782          1
# 2       7.587945            58.571657          0
# 3       6.387926            88.827701          1
# 4       2.404168            81.083870          0
# ..           ...                  ...        ...
# 495     4.180170            45.494924          0
# 496     6.252905            95.038815          1
# 497     1.699612            48.209118          0
# 498     9.769553            97.014241          1
# 499     9.875897            66.760346          1
#
# [500 rows x 3 columns]

# %%
df.shape
# Out:
# (500, 3)

# %%
sns.scatterplot(data =df,x="Study Hours",y="Previous Exam Score",hue= "Pass/Fail")
# Out:
# <Axes: xlabel='Study Hours', ylabel='Previous Exam Score'>

# %% [raw]
# # Perceptron will create one line and it will calculate w1,w2,b

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
from sklearn.linear_model import Perceptron
p = Perceptron()

# %%
p.fit(X,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[441.9410038 , -30.14882699]])

# %%
p.intercept_
# Out:
# array([-421.])

# %%
# pip install mlxtend

# %%
# pip install --upgrade pip

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X.values,y.values,clf=p,legend=2)
plt.title("Perception Demo")
plt.xlabel("Study Hours")
plt.ylabel("Previous Exam Score")
plt.show()
# Out:
# C:\Users\vijay\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
