# %% [markdown]
# **ReNet50 Pretrained Model Used to Classify images :**
# Here is two main reason to use pretrained model
#
# *   deep learning model model is data hungry and need lablled data.
# *   huge training time.
#
# if pretrained model is already available  then used them.

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
model = ResNet50(weights='imagenet')
# Out:
# ...
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# Test Case 1:

# %%
img_path = '/content/watch.webp'
img = image.load_img(img_path,target_size=(224,224))
x = image.img_to_array(img)
x = np.expand_dims(x,axis=0)
x = preprocess_input(x)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
preds  = model.predict(x)
print('Predicted:',decode_predictions(preds,top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# Predicted: [('n02708093', 'analog_clock', 0.4601029), ('n03706229', 'magnetic_compass', 0.42417517), ('n02794156', 'barometer', 0.041751195)]

# %% [markdown]
# Test Case 2:

# %%
img_path = '/content/books.webp'
img = image.load_img(img_path,target_size=(224,224))
x = image.img_to_array(img)
x = np.expand_dims(x,axis=0)
x = preprocess_input(x)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
preds  = model.predict(x)
print('Predicted:',decode_predictions(preds,top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# Predicted: [('n03661043', 'library', 0.42630127), ('n04435653', 'tile_roof', 0.06496996), ('n02871525', 'bookshop', 0.04630458)]

# %% [markdown]
# Test Case 3 :

# %%
img_path = '/content/cat.jpg'
img = image.load_img(img_path,target_size=(224,224))
x = image.img_to_array(img)
x = np.expand_dims(x,axis=0)
x = preprocess_input(x)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
preds = model.predict(x)
print('Predicted:',decode_predictions(preds,top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# Predicted: [('n02123159', 'tiger_cat', 0.49486995), ('n02123045', 'tabby', 0.47875646), ('n02124075', 'Egyptian_cat', 0.012468906)]
